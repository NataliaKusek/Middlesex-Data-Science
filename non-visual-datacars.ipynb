# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
data = pd.read_excel('data-cars.xlsx')

# %%
data.sample(10)
# Out:
#                             Vehicle Name  Sedan  Sports Car  SUV  Wagon  \
# 150               Honda Accord EX V6 2dr      1           0    0      0
# 337                    Saab 9-3 Aero 4dr      1           0    0      0
# 404         Volkswagen Jetta GLI VR6 4dr      1           0    0      0
# 314             Nissan Titan King Cab XE      0           0    0      0
# 419                    Volvo S60 2.5 4dr      1           0    0      0
# 325                      Pontiac Montana      0           0    0      0
# 23   Audi TT 1.8 convertible 2dr (coupe)      0           1    0      0
# 265               Mercedes-Benz E500 4dr      1           0    0      0
# 17               Audi A6 3.0 Quattro 4dr      1           0    0      0
# 42                           BMW X3 3.0i      0           0    1      0
#
#      Minivan  Pickup  AWD  RWD  Retail Price  Dealer Cost  Engine Size (l)  \
# 150        0       0    0    0         26960        24304              3.0
# ...

# %%
data.shape
# Out:
# (428, 20)

# %%
data.isnull().any().any()
# Out:
# False

# %%
data.isin(['*']).any()
# Out:
# Vehicle Name       False
# Sedan              False
# Sports Car         False
# SUV                False
# Wagon              False
# Minivan            False
# Pickup             False
# AWD                False
# RWD                False
# Retail Price       False
# Dealer Cost        False
# Engine Size (l)    False
# Cyl                False
# HP                 False
# City MPG            True
# Hwy MPG             True
# Weight              True
# Wheel Base          True
# Len                 True
# Width               True
# dtype: bool

# %%
data.isin(['*']).sum()
# Out:
# Vehicle Name        0
# Sedan               0
# Sports Car          0
# SUV                 0
# Wagon               0
# Minivan             0
# Pickup              0
# AWD                 0
# RWD                 0
# Retail Price        0
# Dealer Cost         0
# Engine Size (l)     0
# Cyl                 0
# HP                  0
# City MPG           14
# Hwy MPG            14
# Weight              2
# Wheel Base          2
# Len                26
# Width              28
# dtype: int64

# %%
data.loc[(data['Weight'] == '*') | (data['Wheel Base'] == '*') | (data['Len'] == '*')| (data['Hwy MPG'] == '*')  | (data['Width'] == '*') | (data['City MPG'] == '*') ]
# Out:
#                              Vehicle Name  Sedan  Sports Car  SUV  Wagon  \
# 58                  Cadillac Escalade EXT      0           0    0      0
# 64               Chevrolet Avalanche 1500      0           0    0      0
# 70                 Chevrolet Colorado Z85      0           0    0      0
# 82   Chevrolet Silverado 1500 Regular Cab      0           0    0      0
# 83                 Chevrolet Silverado SS      0           0    0      0
# 84                          Chevrolet SSR      0           0    0      0
# 107                 Dodge Dakota Club Cab      0           0    0      0
# 108              Dodge Dakota Regular Cab      0           0    0      0
# 115         Dodge Ram 1500 Regular Cab ST      0           0    0      0
# 118    Dodge Viper SRT-10 convertible 2dr      0           1    0      0
# 123                Ford Excursion 6.8 XLT      0           0    1      0
# 126             Ford F-150 Regular Cab XL      0           0    0      0
# ...

# %%
indexes_to_remove = data[(data['Weight'] == '*') | (data['Wheel Base'] == '*') | (data['Len'] == '*')| (data['Hwy MPG'] == '*')  | (data['Width'] == '*') | (data['City MPG'] == '*') ].index

# %%
data.drop(indexes_to_remove, inplace=True)

# %%
data.isin(['*']).any()
# Out:
# Vehicle Name       False
# Sedan              False
# Sports Car         False
# SUV                False
# Wagon              False
# Minivan            False
# Pickup             False
# AWD                False
# RWD                False
# Retail Price       False
# Dealer Cost        False
# Engine Size (l)    False
# Cyl                False
# HP                 False
# City MPG           False
# Hwy MPG            False
# Weight             False
# Wheel Base         False
# Len                False
# Width              False
# dtype: bool

# %%
data.describe()
# Out:
#             Sedan  Sports Car         SUV       Wagon     Minivan  Pickup  \
# count  387.000000  387.000000  387.000000  387.000000  387.000000   387.0
# mean     0.604651    0.116279    0.152455    0.074935    0.051680     0.0
# std      0.489558    0.320974    0.359926    0.263628    0.221666     0.0
# min      0.000000    0.000000    0.000000    0.000000    0.000000     0.0
# 25%      0.000000    0.000000    0.000000    0.000000    0.000000     0.0
# 50%      1.000000    0.000000    0.000000    0.000000    0.000000     0.0
# 75%      1.000000    0.000000    0.000000    0.000000    0.000000     0.0
# max      1.000000    1.000000    1.000000    1.000000    1.000000     0.0
#
#               AWD         RWD   Retail Price    Dealer Cost  Engine Size (l)  \
# count  387.000000  387.000000     387.000000     387.000000       387.000000
# mean     0.201550    0.242894   33231.180879   30440.653747         3.127390
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 387 entries, 0 to 427
# Data columns (total 20 columns):
# Vehicle Name       387 non-null object
# Sedan              387 non-null int64
# Sports Car         387 non-null int64
# SUV                387 non-null int64
# Wagon              387 non-null int64
# Minivan            387 non-null int64
# Pickup             387 non-null int64
# AWD                387 non-null int64
# RWD                387 non-null int64
# Retail Price       387 non-null int64
# Dealer Cost        387 non-null int64
# Engine Size (l)    387 non-null float64
# Cyl                387 non-null int64
# HP                 387 non-null int64
# City MPG           387 non-null object
# Hwy MPG            387 non-null object
# Weight             387 non-null object
# Wheel Base         387 non-null object
# Len                387 non-null object
# Width              387 non-null object
# dtypes: float64(1), int64(12), object(7)
# memory usage: 73.5+ KB

# %%
black_list = ['Vehicle Name']
object_features = [feature for feature in data.select_dtypes(include='object') if feature not in black_list]

# %%
data[object_features] = data[object_features].astype('int')

# %%
data.corr()
# Out:
#                     Sedan  Sports Car       SUV     Wagon   Minivan  Pickup  \
# Sedan            1.000000   -0.448596 -0.524507 -0.351981 -0.288698     NaN
# Sports Car      -0.448596    1.000000 -0.153845 -0.103241 -0.084679     NaN
# SUV             -0.524507   -0.153845  1.000000 -0.120711 -0.099008     NaN
# Wagon           -0.351981   -0.103241 -0.120711  1.000000 -0.066442     NaN
# Minivan         -0.288698   -0.084679 -0.099008 -0.066442  1.000000     NaN
# Pickup                NaN         NaN       NaN       NaN       NaN     NaN
# AWD             -0.305156   -0.081778  0.449928  0.077188 -0.029998     NaN
# RWD             -0.034966    0.396053 -0.240226 -0.001005 -0.105006     NaN
# Retail Price    -0.218115    0.389707  0.031127 -0.057784 -0.064403     NaN
# Dealer Cost     -0.211318    0.383799  0.026147 -0.054734 -0.066400     NaN
# Engine Size (l) -0.278646    0.090455  0.311410 -0.096828  0.093933     NaN
# ...

# %%
plt.figure(figsize=(15,15))
sns.heatmap(data.corr(method='spearman'), annot=True, cmap='YlGnBu');

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 428 entries, 0 to 427
# Data columns (total 20 columns):
# Vehicle Name       428 non-null object
# Sedan              428 non-null int64
# Sports Car         428 non-null int64
# SUV                428 non-null int64
# Wagon              428 non-null int64
# Minivan            428 non-null int64
# Pickup             428 non-null int64
# AWD                428 non-null int64
# RWD                428 non-null int64
# Retail Price       428 non-null int64
# Dealer Cost        428 non-null int64
# Engine Size (l)    428 non-null float64
# Cyl                428 non-null int64
# HP                 428 non-null int64
# City MPG           428 non-null object
# Hwy MPG            428 non-null object
# Weight             428 non-null object
# Wheel Base         428 non-null object
# Len                428 non-null object
# Width              428 non-null object
# dtypes: float64(1), int64(12), object(7)
# memory usage: 67.0+ KB

# %%
data.set_index(['Sedan','Sports Car']).unstack(['City MPG'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/multi.py in _get_level_number(self, level)
#     775                                  'level number' % level)
# --> 776             level = self.names.index(level)
#     777         except ValueError:
#
# ValueError: 'City MPG' is not in list
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-119-d0fdfd694e16> in <module>()
# ----> 1 data.set_index(['Sedan','Sports Car']).unstack(['City MPG'])
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in unstack(self, level, fill_value)
#    5529         """
#    5530         from pandas.core.reshape.reshape import unstack
# -> 5531         return unstack(self, level, fill_value)
#    5532
# ...

# %%
g = data.groupby('Sedan')
g.max()
# Out:
#            Vehicle Name  Sports Car  SUV  Wagon  Minivan  Pickup  AWD  RWD  \
# Sedan
# 0         Volvo XC90 T6           1    1      1        1       1    1    1
# 1      Volvo S80 T6 4dr           0    0      0        0       0    1    1
#
#        Retail Price  Dealer Cost  Engine Size (l)  Cyl   HP
# Sedan
# 0            192465       173560              8.3   12  500
# 1            128420       119600              6.0   12  493
